# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('temperature_data (1).csv')
df
# Out:
#          ambient   coolant       u_d       u_q  motor_speed    torque  \
# 0      -0.752143 -1.118446  0.327935 -1.297858    -1.222428 -0.250182
# 1      -0.771263 -1.117021  0.329665 -1.297686    -1.222429 -0.249133
# 2      -0.782892 -1.116681  0.332771 -1.301822    -1.222428 -0.249431
# 3      -0.780935 -1.116764  0.333700 -1.301852    -1.222430 -0.248636
# 4      -0.774043 -1.116775  0.335206 -1.303118    -1.222429 -0.248701
# ...          ...       ...       ...       ...          ...       ...
# 998065 -0.047497  0.341638  0.331475 -1.246114    -1.222428 -0.255640
# 998066 -0.048839  0.320022  0.331701 -1.250655    -1.222437 -0.255640
# 998067 -0.042350  0.307415  0.330946 -1.246852    -1.222430 -0.255640
# 998068 -0.039433  0.302082  0.330987 -1.249505    -1.222432 -0.255640
# 998069 -0.043803  0.312666  0.330830 -1.246590    -1.222431 -0.255640
#
#              i_d       i_q        pm  stator_yoke  stator_tooth  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 998070 entries, 0 to 998069
# Data columns (total 13 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   ambient         998070 non-null  float64
#  1   coolant         998070 non-null  float64
#  2   u_d             998070 non-null  float64
#  3   u_q             998070 non-null  float64
#  4   motor_speed     998070 non-null  float64
#  5   torque          998070 non-null  float64
#  6   i_d             998070 non-null  float64
#  7   i_q             998070 non-null  float64
#  8   pm              998070 non-null  float64
#  9   stator_yoke     998070 non-null  float64
#  10  stator_tooth    998070 non-null  float64
#  11  stator_winding  998070 non-null  float64
#  12  profile_id      998070 non-null  int64
# dtypes: float64(12), int64(1)
# memory usage: 99.0 MB

# %%
df.drop(columns=['profile_id'], inplace=True)
df.head(5)
# Out:
#     ambient   coolant       u_d       u_q  motor_speed    torque       i_d  \
# 0 -0.752143 -1.118446  0.327935 -1.297858    -1.222428 -0.250182  1.029572
# 1 -0.771263 -1.117021  0.329665 -1.297686    -1.222429 -0.249133  1.029509
# 2 -0.782892 -1.116681  0.332771 -1.301822    -1.222428 -0.249431  1.029448
# 3 -0.780935 -1.116764  0.333700 -1.301852    -1.222430 -0.248636  1.032845
# 4 -0.774043 -1.116775  0.335206 -1.303118    -1.222429 -0.248701  1.031807
#
#         i_q        pm  stator_yoke  stator_tooth  stator_winding
# 0 -0.245860 -2.522071    -1.831422     -2.066143       -2.018033
# 1 -0.245832 -2.522418    -1.830969     -2.064859       -2.017631
# 2 -0.245818 -2.522673    -1.830400     -2.064073       -2.017343
# 3 -0.246955 -2.521639    -1.830333     -2.063137       -2.017632
# 4 -0.246610 -2.521900    -1.830498     -2.062795       -2.018145

# %%
df.describe()
# Out:
#              ambient        coolant            u_d            u_q  \
# count  998070.000000  998070.000000  998070.000000  998070.000000
# mean       -0.003905       0.004723       0.004780      -0.005690
# std         0.993127       1.002423       0.997878       1.002330
# min        -8.573954      -1.429349      -1.655373      -1.861463
# 25%        -0.599385      -1.037925      -0.826359      -0.927390
# 50%         0.266157      -0.177187       0.267542      -0.099818
# 75%         0.686675       0.650709       0.358491       0.852625
# max         2.967117       2.649032       2.274734       1.793498
#
#          motor_speed         torque            i_d            i_q  \
# count  998070.000000  998070.000000  998070.000000  998070.000000
# mean       -0.006336      -0.003333       0.006043      -0.003194
# std         1.001229       0.997907       0.998994       0.997912
# min        -1.371529      -3.345953      -3.245874      -3.341639
# ...

# %%
df.isnull().sum()
# Out:
# ambient           0
# coolant           0
# u_d               0
# u_q               0
# motor_speed       0
# torque            0
# i_d               0
# i_q               0
# pm                0
# stator_yoke       0
# stator_tooth      0
# stator_winding    0
# dtype: int64

# %%
df[df.duplicated()].sum()
# Out:
# ambient           0.0
# coolant           0.0
# u_d               0.0
# u_q               0.0
# motor_speed       0.0
# torque            0.0
# i_d               0.0
# i_q               0.0
# pm                0.0
# stator_yoke       0.0
# stator_tooth      0.0
# stator_winding    0.0
# dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(25,10))
sns.boxplot(data=df)
plt.show()

# %%
Q1 = df['ambient'].quantile(0.25)
Q3 = df['ambient'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
df['ambient'] = df['ambient'].apply(lambda x: lower_bound if x < lower_bound else upper_bound if x > upper_bound else x)

# %%
plt.figure(figsize=(10,5))
sns.boxplot(y = df['ambient'], data=df)
plt.show()

# %%
Q1 = df['u_d'].quantile(0.25)
Q3 = df['u_d'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
df['u_d'] = df['u_d'].apply(lambda x: lower_bound if x < lower_bound else upper_bound if x > upper_bound else x)

# %%
plt.figure(figsize=(10,5))
sns.boxplot(y = df['u_d'], data=df)
plt.show()

# %%
Q1 = df['torque'].quantile(0.25)
Q3 = df['torque'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
df['torque'] = df['torque'].apply(lambda x: lower_bound if x < lower_bound else upper_bound if x > upper_bound else x)

# %%
plt.figure(figsize=(10,5))
sns.boxplot(y = df['torque'], data=df)
plt.show()

# %%
Q1 = df['i_q'].quantile(0.25)
Q3 = df['i_q'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
df['i_q'] = df['i_q'].apply(lambda x: lower_bound if x < lower_bound else upper_bound if x > upper_bound else x)

# %%
plt.figure(figsize=(10,5))
sns.boxplot(y = df['i_q'], data=df)
plt.show()

# %%
Q1 = df['pm'].quantile(0.25)
Q3 = df['pm'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
df['pm'] = df['pm'].apply(lambda x: lower_bound if x < lower_bound else upper_bound if x > upper_bound else x)

# %%
plt.figure(figsize=(10,5))
sns.boxplot(y = df['pm'], data=df)
plt.show()

# %%
#Checking correlation
# correlation Matrix
corr_matrix  = df.corr()

# plot heatmap
plt.figure(figsize=(6,6))
sns.heatmap(corr_matrix, annot=True, cmap= 'coolwarm', linewidths=0.5, fmt= '.2f')
plt.title('Heatmap of Correlation Matrix')
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_df = pd.DataFrame(scaler.fit_transform(df), columns= df.columns)
scaled_df.head(10)
# Out:
#     ambient   coolant       u_d       u_q  motor_speed    torque       i_d  \
# 0 -0.783789 -1.120454  0.325709 -1.289164    -1.214600 -0.314976  1.024560
# 1 -0.803565 -1.119032  0.327446 -1.288994    -1.214601 -0.313747  1.024497
# 2 -0.815593 -1.118693  0.330567 -1.293119    -1.214600 -0.314096  1.024435
# 3 -0.813569 -1.118776  0.331500 -1.293150    -1.214602 -0.313164  1.027836
# 4 -0.806440 -1.118787  0.333013 -1.294413    -1.214601 -0.313240  1.026797
# 5 -0.794953 -1.118966  0.332706 -1.294312    -1.214601 -0.312649  1.026020
# 6 -0.780774 -1.118184  0.332819 -1.293379    -1.214602 -0.312318  1.025482
# 7 -0.769626 -1.116005  0.334068 -1.296445    -1.214604 -0.312795  1.025096
# 8 -0.761828 -1.113851  0.332711 -1.295083    -1.214603 -0.312166  1.024840
# 9 -0.757918 -1.111515  0.333798 -1.296922    -1.214603 -0.312764  1.024624
#
#         i_q        pm  stator_yoke  stator_tooth  stator_winding
# 0 -0.324420 -2.529653    -1.830112     -2.064767       -2.017442
# ...

# %%
features = scaled_df.drop(columns=['motor_speed'])
target = scaled_df['motor_speed']
features.head(5)
# Out:
#     ambient   coolant       u_d       u_q    torque       i_d       i_q  \
# 0 -0.783789 -1.120454  0.325709 -1.289164 -0.314976  1.024560 -0.324420
# 1 -0.803565 -1.119032  0.327446 -1.288994 -0.313747  1.024497 -0.324386
# 2 -0.815593 -1.118693  0.330567 -1.293119 -0.314096  1.024435 -0.324369
# 3 -0.813569 -1.118776  0.331500 -1.293150 -0.313164  1.027836 -0.325747
# 4 -0.806440 -1.118787  0.333013 -1.294413 -0.313240  1.026797 -0.325329
#
#          pm  stator_yoke  stator_tooth  stator_winding
# 0 -2.529653    -1.830112     -2.064767       -2.017442
# 1 -2.530001    -1.829659     -2.063483       -2.017040
# 2 -2.530258    -1.829091     -2.062697       -2.016752
# 3 -2.529219    -1.829024     -2.061760       -2.017041
# 4 -2.529481    -1.829189     -2.061418       -2.017555

# %%
target.head(10)
# Out:
# 0   -1.214600
# 1   -1.214601
# 2   -1.214600
# 3   -1.214602
# 4   -1.214601
# 5   -1.214601
# 6   -1.214602
# 7   -1.214604
# 8   -1.214603
# 9   -1.214603
# Name: motor_speed, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(features, target, test_size = 0.20, random_state= 100)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (798456, 11)
# (199614, 11)
# (798456,)
# (199614,)

# %%
#Using Linear Regression Model

# %%
from sklearn.linear_model import LinearRegression
linear_model = LinearRegression()
linear_model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
prediction =pd.DataFrame( linear_model.predict(x_test), columns=['linear_pred'])
prediction
# Out:
#         linear_pred
# 0         -0.603530
# 1         -0.370346
# 2         -1.168980
# 3         -0.292779
# 4          1.281552
# ...             ...
# 199609     1.032248
# 199610    -1.414565
# 199611    -0.144469
# 199612    -1.351309
# 199613     1.712500
#
# [199614 rows x 1 columns]

# %%
#Finding performance matrix

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
linear_mae = mean_absolute_error(y_test, prediction['linear_pred'])
print('Mean absolute error', linear_mae)
linear_mse  = mean_squared_error(y_test,prediction['linear_pred'])
print('Mean squared error', linear_mse)
linear_r2 = r2_score(y_test,prediction['linear_pred'])
print('r2 score', linear_r2)
# Out:
# Mean absolute error 0.18438356694671135
# Mean squared error 0.06168489971403185
# r2 score 0.9383764607922979

# %%
#Using K Nearest Naighbour Model

# %%
from sklearn.neighbors import KNeighborsRegressor
knn_model = KNeighborsRegressor(n_neighbors=5)
knn_model.fit(x_train, y_train)
# Out:
# KNeighborsRegressor()

# %%
prediction['knn_pred'] = knn_model.predict(x_test)
prediction
# Out:
#         linear_pred  knn_pred
# 0         -0.603530 -0.805468
# 1         -0.370346 -0.329899
# 2         -1.168980 -1.214602
# 3         -0.292779 -0.403957
# 4          1.281552  1.552390
# ...             ...       ...
# 199609     1.032248  0.889307
# 199610    -1.414565 -1.214605
# 199611    -0.144469 -0.133748
# 199612    -1.351309 -1.214602
# 199613     1.712500  1.892863
#
# [199614 rows x 2 columns]

# %%
#Applying Performance matrix on KNN

# %%
knn_mae = mean_absolute_error(y_test, prediction['knn_pred'])
print('Mean absolute error', knn_mae)
knn_mse  = mean_squared_error(y_test, prediction['knn_pred'])
print('Mean squared error', knn_mse)
knn_r2 = r2_score(y_test, prediction['knn_pred'])
print('r2 score', knn_r2)
# Out:
# Mean absolute error 0.012163897121634019
# Mean squared error 0.0009176568064637996
# r2 score 0.9990832560244971

# %%
#Using Random Forest Model

# %%
from sklearn.ensemble import RandomForestRegressor
rf_model = RandomForestRegressor(n_estimators=10, random_state=42)
rf_model.fit(x_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=10, random_state=42)

# %%
prediction['rf_pred'] = rf_model.predict(x_test)
prediction
# Out:
#         linear_pred  knn_pred   rf_pred
# 0         -0.603530 -0.805468 -0.786432
# 1         -0.370346 -0.329899 -0.311139
# 2         -1.168980 -1.214602 -1.214603
# 3         -0.292779 -0.403957 -0.403957
# 4          1.281552  1.552390  1.552391
# ...             ...       ...       ...
# 199609     1.032248  0.889307  0.941399
# 199610    -1.414565 -1.214605 -1.214603
# 199611    -0.144469 -0.133748 -0.133748
# 199612    -1.351309 -1.214602 -1.214602
# 199613     1.712500  1.892863  1.892865
#
# [199614 rows x 3 columns]

# %%
#Applying Perfomance matrix for Random Forest

# %%
rf_mae = mean_absolute_error(y_test, prediction['rf_pred'])
print('Mean absolute error', rf_mae)
rf_mse  = mean_squared_error(y_test, prediction['rf_pred'])
print('Mean squared error', rf_mse)
rf_r2 = r2_score(y_test, prediction['rf_pred'])
print('r2 score', rf_r2)
# Out:
# Mean absolute error 0.004559398097039212
# Mean squared error 0.00019010627511319942
# r2 score 0.9998100828314161

# %%
#Report of 3 models

# %%
report = pd.DataFrame({'Models':['LinearRegression Model','KNeighborsRegressor Model','RandomForestRegressor'], 'Mean_adsolute_error':[linear_mae, knn_mae, rf_mae],'Mean_squared_error':[linear_mse, knn_mse, rf_mse], 'R2_error':[linear_r2, knn_r2, rf_r2]})
report
# Out:
#                       Models  Mean_adsolute_error  Mean_squared_error  \
# 0     LinearRegression Model             0.184384            0.061685
# 1  KNeighborsRegressor Model             0.012164            0.000918
# 2      RandomForestRegressor             0.004559            0.000190
#
#    R2_error
# 0  0.938376
# 1  0.999083
# 2  0.999810

# %%
plt.figure(figsize=(6,6))
sns.scatterplot(x=report['Mean_adsolute_error'], 
                y=report['R2_error'], 
                hue=report['Models'])
# Out:
# <Axes: xlabel='Mean_adsolute_error', ylabel='R2_error'>

# %%
#we are getting less errors in Random Forest Model
#We are finding Random Forest Model as Good Model

# %%
import pickle

# %%
file='ramf.pkl'

# %%
pickle.dump(rf_model,open(file,'wb'))

# %%
# !pip install -q streamlit
